# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
os.chdir('C:/DBAR')
df_red=pd.read_csv('wine_red.csv')
df_white=pd.read_csv('wine_white2.csv')

# %%
df_red.shape
# Out:
# (1599, 12)

# %%
df_white.shape
# Out:
# (4898, 12)

# %%
df_white.columns
# Out:
# Index(['fixed.acidity', 'volatile.acidity', 'citric.acid', 'residual.sugar',
#        'chlorides', 'free.sulfur.dioxide', 'total.sulfur.dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df_red.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df_white.rename(columns={'fixed.acidity': 'fixed_acidity','citric.acid':'citric_acid','volatile.acidity':'volatile_acidity','residual.sugar':'residual_sugar','free.sulfur.dioxide':'free_sulfur_dioxide','total.sulfur.dioxide':'total_sulfur_dioxide'}, inplace=True)

# %%
df_red.rename(columns={'fixed acidity': 'fixed_acidity','citric acid':'citric_acid','volatile acidity':'volatile_acidity','residual sugar':'residual_sugar','free sulfur dioxide':'free_sulfur_dioxide','total sulfur dioxide':'total_sulfur_dioxide'}, inplace=True)

# %%
df_all=pd.concat([df_red,df_white],axis=0)

# %%
df_all.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df_all.shape
# Out:
# (6497, 12)

# %%
df_red['quality'].mean()
# Out:
# 5.6360225140712945

# %%
df_white['quality'].mean()
# Out:
# 5.87790935075541

# %%
df_all.isnull().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ## No Missing Values..

# %%
df_all.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %% [markdown]
# ## Data Preprocessing!!!!

# %%
df_all['quality'].value_counts()
# Out:
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: quality, dtype: int64

# %%
df_all['quality']=df_all['quality'].map({3:'bad', 4:'bad', 5:'bad', 6:'good', 7:'good', 8:'good', 9:'good'})

# %%
df_all['quality'].value_counts()
# Out:
# good    4113
# bad     2384
# Name: quality, dtype: int64

# %%
df_all.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality
# 0      9.4     bad
# 1      9.8     bad
# 2      9.8     bad
# ...

# %%
df_all['quality']=df_all['quality'].map({'good':1 , 'bad':0})

# %%
df_all.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        0
# 1      9.8        0
# 2      9.8        0
# ...

# %% [markdown]
# ## Data Visualization..

# %% [markdown]
# ## Bivariate Analysis

# %%
plt.scatter(df_red['quality'], df_red['fixed_acidity'], color = 'red')
plt.title('relation of fixed acidity with wine')
plt.xlabel('quality')
plt.ylabel('fixed_acidity')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.scatter(df_white['quality'], df_white['fixed_acidity'], color = 'purple')
plt.title('relation of fixed acidity with wine')
plt.xlabel('quality')
plt.ylabel('fixed_acidity')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
df_both=pd.concat([df_red,df_white],axis=0)

# %%
plt.bar(df_both['quality'], df_both['alcohol'], color = 'maroon')
plt.title('relation of alcohol with wine')
plt.xlabel('quality')
plt.ylabel('alcohol')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import seaborn as sns
fig = plt.figure(figsize = (12,7))
sns.barplot(x = 'quality', y = 'citric_acid', data = df_both)

# %%
fig = plt.figure(figsize = (12,7))
sns.barplot(x = 'quality', y = 'residual_sugar', data = df_both)

# %%
fig = plt.figure(figsize = (12,7))
sns.barplot(x = 'quality', y = 'chlorides', data = df_both)

# %%
fig = plt.figure(figsize = (12,7))
sns.barplot(x = 'quality', y = 'free_sulfur_dioxide', data = df_both)

# %%
fig = plt.figure(figsize = (12,7))
sns.barplot(x = 'quality', y = 'sulphates', data = df_both)

# %% [markdown]
# ## Correlation Heatmaps- Seaborn

# %% [markdown]
# ## RED WINE..

# %%
plt.subplots(figsize=(12,9))
ax = plt.axes()
ax.set_title("Wine Characteristic Correlation Heatmap (Reds)")
corr = df_red.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
           cmap="Reds",annot=True)
plt.show()

# %% [markdown]
# ## WHITE WINE...

# %%
plt.subplots(figsize=(12,9))
ax = plt.axes()
ax.set_title("Wine Characteristic Correlation Heatmap (Whites)")
corr = df_white.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
           cmap="Purples",annot=True)

# %%
df_both_r_corr=df_red.corr()
df_both_w_corr=df_white.corr()

# %%
df_both_r_corr
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000         -0.256131     0.671703
# volatile_acidity          -0.256131          1.000000    -0.552496
# citric_acid                0.671703         -0.552496     1.000000
# residual_sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free_sulfur_dioxide       -0.153794         -0.010504    -0.060978
# total_sulfur_dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# ...

# %%
df_both_w_corr
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000         -0.022697     0.289181
# volatile_acidity          -0.022697          1.000000    -0.149472
# citric_acid                0.289181         -0.149472     1.000000
# residual_sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free_sulfur_dioxide       -0.049396         -0.097012     0.094077
# total_sulfur_dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# ...

# %%
diff_corr=df_both_r_corr - df_both_w_corr

# %%
plt.subplots(figsize=(12,9))
ax = plt.axes()
ax.set_title("Correlation Differences between Red and White Wines")
corr = diff_corr
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
           cmap="coolwarm")

# %%
sns.pairplot(df_both)

# %% [markdown]
# ## As we see from correlation heatmaps that some of the features does not hold strong correlation, we can drop those features for a better model.

# %%
df_all2=df_all.drop(['volatile_acidity','chlorides','density'],axis=1)

# %%
df_all.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        0
# 1      9.8        0
# 2      9.8        0
# ...

# %%
df_all2.head()
# Out:
#    fixed_acidity  citric_acid  residual_sugar  free_sulfur_dioxide  \
# 0            7.4         0.00             1.9                 11.0
# 1            7.8         0.00             2.6                 25.0
# 2            7.8         0.04             2.3                 15.0
# 3           11.2         0.56             1.9                 17.0
# 4            7.4         0.00             1.9                 11.0
#
#    total_sulfur_dioxide    pH  sulphates  alcohol  quality
# 0                  34.0  3.51       0.56      9.4        0
# 1                  67.0  3.20       0.68      9.8        0
# 2                  54.0  3.26       0.65      9.8        0
# 3                  60.0  3.16       0.58      9.8        1
# 4                  34.0  3.51       0.56      9.4        0

# %% [markdown]
# ## Segragating independent and dependent variable

# %%
x=df_all2.drop(['quality'],axis=1)
y=df_all2['quality']
x.shape,y.shape
# Out:
# ((6497, 8), (6497,))

# %%
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y=train_test_split(x,y, test_size=0.3,random_state=42)

# %%
train_x.shape,test_x.shape
# Out:
# ((4547, 8), (1950, 8))

# %%
df_all2['quality'].value_counts()
# Out:
# 1    4113
# 0    2384
# Name: quality, dtype: int64

# %% [markdown]
# ## Normalising independent variables

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
train_x=scaler.fit_transform(train_x)
test_x=scaler.fit_transform(test_x)

# %% [markdown]
# ## Implementing Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression as LogReg
from sklearn.metrics import f1_score

# %%
logreg=LogReg(random_state=96)
logreg.fit(train_x,train_y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=96, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
train_predict=logreg.predict(train_x)
train_predict
# Out:
# array([0, 1, 0, ..., 0, 1, 0], dtype=int64)

# %%
k=f1_score(train_predict,train_y)
print('Training F1_score',  k)
# Out:
# Training F1_score 0.7711088504577823

# %%
test_predict = logreg.predict(test_x)
k = f1_score(test_predict, test_y)
print('Test f1_score    ', k )
# Out:
# Test f1_score     0.7817614964925955

# %%
train_predict = logreg.predict_proba(train_x)
train_predict
# Out:
# array([[0.78353106, 0.21646894],
#        [0.38164457, 0.61835543],
#        [0.57351784, 0.42648216],
#        ...,
#        [0.55328411, 0.44671589],
#        [0.49620177, 0.50379823],
#        [0.73754788, 0.26245212]])

# %%
train_preds = train_predict[:,1]
train_preds
# Out:
# array([0.21646894, 0.61835543, 0.42648216, ..., 0.44671589, 0.50379823,
#        0.26245212])

# %%
for i in range(0, len(train_preds)):
  if(train_preds[i]>0.55):
    train_preds[i] = 1
  else:
    train_preds[i] = 0

# %%
k = f1_score(train_preds, train_y)
print('Training f1_score', k )
# Out:
# Training f1_score 0.7544931703810207

# %%
from sklearn.metrics import confusion_matrix
cf= confusion_matrix(test_y, test_predict)
print(cf)
# Out:
# [[ 387  304]
#  [ 256 1003]]

# %%
from sklearn.metrics import classification_report as rep
print(rep( test_y , test_predict ))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.56      0.58       691
#            1       0.77      0.80      0.78      1259
#
#     accuracy                           0.71      1950
#    macro avg       0.68      0.68      0.68      1950
# weighted avg       0.71      0.71      0.71      1950

# %% [markdown]
# ## Building a Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(random_state=200)

# %%
clf.fit(train_x,train_y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=200, splitter='best')

# %%
clf.score(train_x, train_y)
# Out:
# 1.0

# %%
clf.score(test_x, test_y)
# Out:
# 0.7353846153846154

# %% [markdown]
# ## Building a Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier(random_state=200)

# %%
clf.fit(train_x,train_y)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=200,
#                        verbose=0, warm_start=False)

# %%
clf.score(train_x, train_y)
# Out:
# 1.0

# %%
clf.score(test_x, test_y)
# Out:
# 0.8082051282051282

# %%
clf.feature_importances_
# Out:
# array([0.10106539, 0.12452022, 0.11305178, 0.11780123, 0.12387751,
#        0.10209575, 0.1056384 , 0.21194971])

# %% [markdown]
# ## As we can see our model has a overfitting problem, use of cross validation may help to reduce it

# %% [markdown]
# ## Importing KNN

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN

# %%
from sklearn.model_selection import cross_val_score
score = cross_val_score( KNN(n_neighbors = 3), X = train_x, y = train_y, cv = 10)
score
# Out:
# array([0.74505495, 0.70549451, 0.74945055, 0.77582418, 0.72307692,
#        0.71648352, 0.74285714, 0.75110132, 0.72907489, 0.74889868])

# %%
score.mean()*100, score.std()*100
# Out:
# (73.87316648109599, 1.93446167761496)

# %% [markdown]
# ## Automating the process of cross validation for different K-Neighbors

# %%
def Val_score(n_neighbors):
    '''
  takes range of n_neighbors as input
  returns Mean and Standard Deviation for each value of n_neighbors
  '''
    avg = []
    std = []
  
    for i in n_neighbors:
    
    # 10 fold cross validation for every value of n_neighbor
      score = cross_val_score( KNN(n_neighbors = i) , X = train_x, y = train_y, cv = 10)
    
    # adding mean to avg list
      avg.append(score.mean())
    
    # adding standard deviation to std list
      std.append(score.std())
    
    return avg, std

# %%
n_neighbors = range(1,50)
mean, std = Val_score(n_neighbors)

# %% [markdown]
# ## Plotting Mean Validation Score for each K value

# %%
plt.plot(n_neighbors[10:20], mean[10:20], color = 'green', label = 'mean' )
plt.xlabel('n_neighbors')
plt.ylabel('Mean Score')
plt.title('Mean Validation score')
# Out:
# Text(0.5, 1.0, 'Mean Validation score')

# %% [markdown]
# ## Ploting Standard Deviation Validation Score for each K value

# %%
plt.plot(n_neighbors[10:20], std[10:20], color = 'red', label = 'Standard deviation' )
plt.xlabel('n_neighbors')
plt.ylabel('magnitude')
plt.title('Standard Deviation of Validation score')
# Out:
# Text(0.5, 1.0, 'Standard Deviation of Validation score')

# %% [markdown]
# ## Trying the optimal model over test test.

# %%
clf = KNN(n_neighbors = 16 )
clf.fit(train_x, train_y)

score1 = clf.score(train_x, train_y)

score = clf.score(test_x, test_y)
score, score1
# Out:
# (0.7369230769230769, 0.7776555970969871)
